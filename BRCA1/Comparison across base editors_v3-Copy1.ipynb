# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import gpplot as gpp
from matplotlib import rc

# Set default settings for plotting
sns.set(style='ticks',context='paper')
mpl.rc('pdf', fonttype=42)
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"

# %%
#2021-05-07 AKS updated with newly filtered data
brca1_ng_cbe = pd.read_csv('../../data_v3/Fig 5_6_BRCA1/processed/BRCA1-NG-CBE_LFC.csv')

# %%
print(brca1_ng_cbe.shape)
brca1_ng_cbe.head()
# Out:
# (11641, 43)
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  CTGTTCCAATGAACTTTAAC         BRCA1          -0.778097          -1.102872
# 1  ATGTGTTAAAGTTCATTGGA         BRCA1          -0.060195           0.126319
# 2  TCTGTTCCAATGAACTTTAA         BRCA1          -0.579206          -0.268600
# 3  TGTGTTAAAGTTCATTGGAA         BRCA1           0.316748           0.022198
# 4  TTCTGTTCCAATGAACTTTA         BRCA1          -0.408376          -0.247209
#
#    HAP1_Dropout_RepC  Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  \
# 0          -1.243311             -0.832843             -0.715490
# 1           0.332845              0.154970              0.123453
# 2          -0.355417             -0.428716             -0.097972
# 3           0.363735              0.051371             -0.022138
# 4          -0.473564             -0.209041             -0.295195
#
#    Meljuso_Dropout_RepC  Meljuso_Cisplatin_RepA  Meljuso_Cisplatin_RepB  ...  \
# 0             -0.799696               -0.935742               -0.787923  ...
# 1              0.031662                0.157643                0.094979  ...
# 2             -0.470759               -0.365912               -0.347365  ...
# 3             -0.022786                0.055790               -0.048526  ...
# 4             -0.205968               -0.399921               -0.364444  ...
#
#    Nucleotide edits  Amino acid edits  Mutation category  \
# 0          C_6;C_7;          utr;utr;           UTR;UTR;
# 1               NaN               NaN                NaN
# 2          C_7;C_8;          utr;utr;           UTR;UTR;
# 3               NaN               NaN                NaN
# 4              C_8;              utr;               UTR;
#
#          Clinical significance  BsmBI flag 4T flag AvgHAP1_Meljuso;z-score  \
# 0  None;Uncertain significance         NaN     NaN               -9.051298
# 1                          NaN         NaN     NaN               -0.797852
# 2  Uncertain significance;None         NaN     NaN               -4.721485
# 3                          NaN         NaN     NaN               -1.027600
# 4                         None         NaN     NaN               -4.515973
#
#   Mutation bin  Residues Median Residues
# 0          UTR  utr;utr;             NaN
# 1     No edits       NaN             NaN
# 2          UTR  utr;utr;             NaN
# 3     No edits       NaN             NaN
# 4          UTR      utr;             NaN
#
# [5 rows x 43 columns]

# %%
brca_wt_cbe = pd.read_csv('../../data_v3/Fig 5_6_BRCA1/processed/BRCA1-WT-CBE_LFC.csv')

# %% [markdown]
# # Compare CBEs

# %%
print(brca_wt_cbe.shape)
brca_wt_cbe.head()
# Out:
# (723, 38)
#       Construct Barcode                          Construct IDs  \
# 0  TTCATTGGAACAGAAAGAAA            TTCATTGGAACAGAAAGAAA;BRCA1;
# 1  AAATCTTAGAGTGTCCCATC       AAATCTTAGAGTGTCCCATC;BRCA1;I21I;
# 2  CTTGTGCTGACTTACCAGAT   CTTGTGCTGACTTACCAGAT;BRCA1;Exon2:+9;
# 3  TCTTGTGCTGACTTACCAGA   TCTTGTGCTGACTTACCAGA;BRCA1;Exon2:+9;
# 4  AGCACAAGAGTGTATTAATT  AGCACAAGAGTGTATTAATT;BRCA1;Exon2:+12;
#
#    HAP1_Dropout_RepA  HAP1_Dropout_RepB  HAP1_Dropout_RepC  \
# 0          -0.950986          -0.884010          -0.818571
# 1           0.348789           0.287101           0.185596
# 2           0.190411           0.140385           0.296765
# 3          -0.196196          -0.306559          -0.227523
# 4           0.540360           0.505754           0.521858
#
#    Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  Meljuso_Dropout_RepC  \
# 0             -0.885524             -0.848881             -0.856270
# 1              0.336294              0.207309              0.109502
# 2             -0.703793             -0.265804             -0.677387
# 3             -2.333888             -2.474497             -1.926979
# 4              0.397165              0.281295              0.384297
#
#    Meljuso_Cisplatin_RepA  Meljuso_Cisplatin_RepB  ...  # silent edits  \
# 0               -0.962905               -0.881408  ...             0.0
# 1                0.250728                0.104310  ...             1.0
# 2                0.094742                0.028039  ...             0.0
# 3               -0.660860               -0.628593  ...             0.0
# 4                0.338703                0.348768  ...             0.0
#
#    Nucleotide edits  Amino acid edits  Mutation category  \
# 0               NaN               NaN                NaN
# 1              C_5;         Ile21Ile;            Silent;
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4              C_5;        Exon2:+12;            Intron;
#
#    Clinical significance Match Bin I counts AvgHAP1_Meljuso;z-score  \
# 0                    NaN                  1               -3.287739
# 1          Likely benign                  0                0.178913
# 2                    NaN                  0               -0.158507
# 3                    NaN                  0               -1.806541
# 4                   None                  1                0.759998
#
#   Mutation bin Residues Median Residues
# 0     No edits      NaN             NaN
# 1       Silent      21;            21.0
# 2     No edits      NaN             NaN
# 3     No edits      NaN             NaN
# 4       Intron  intron;             NaN
#
# [5 rows x 38 columns]

# %%
#rename columns such that we can tell them apart
brca1_ng_cbe = brca1_ng_cbe.rename(columns={'AvgHAP1_Meljuso;z-score': 'AvgHAP1_Meljuso;z-score;NG-CBE'})

brca_wt_cbe = brca_wt_cbe.rename(columns={'AvgHAP1_Meljuso;z-score': 'AvgHAP1_Meljuso;z-score;WT-CBE'})

# %%
#merge on shared sgRNAs between wt and ng

wt_ng_cbe = pd.merge(brca1_ng_cbe, brca_wt_cbe, on= ['Construct Barcode'], how='inner')

# %%
wt_ng_cbe = wt_ng_cbe[['Construct Barcode', 'Construct IDs_x', 'AvgHAP1_Meljuso;z-score;NG-CBE',
                    'AvgHAP1_Meljuso;z-score;WT-CBE', 'PAM_x', 'Edit_x', 'Amino acid edits_x', 
                    'Mutation bin_x', 'Clinical significance_x']]

# %%
print(wt_ng_cbe.shape)
wt_ng_cbe.head()
# Out:
# (547, 9)
#       Construct Barcode Construct IDs_x  AvgHAP1_Meljuso;z-score;NG-CBE  \
# 0  AAATCTTAGAGTGTCCCATC           BRCA1                       -1.365564
# 1  CTTGTGCTGACTTACCAGAT           BRCA1                       -0.870621
# 2  TCTTGTGCTGACTTACCAGA           BRCA1                       -3.666501
# 3  AGCACAAGAGTGTATTAATT           BRCA1                        0.131991
# 4  CCAGACTAGCAGGGTAGGGG           BRCA1                       -6.463929
#
#    AvgHAP1_Meljuso;z-score;WT-CBE PAM_x Edit_x Amino acid edits_x  \
# 0                        0.178913  TGGT    C-T          Ile21Ile;
# 1                       -0.158507  GGGA    C-T          Exon2:+9;
# 2                       -1.806541  TGGG    C-T          Exon2:+9;
# 3                        0.759998  TGGG    C-T         Exon2:+12;
# 4                       -8.200470  GGGA    C-T          Exon3:-1;
#
#   Mutation bin_x       Clinical significance_x
# 0         Silent                 Likely benign
# 1         Intron                          None
# 2         Intron                          None
# 3         Intron                          None
# 4    Splice site  Pathogenic/Likely pathogenic

# %%
#plot only sgRNAs targeting BRCA1
wt_ng_cbe = wt_ng_cbe[wt_ng_cbe['Construct IDs_x'] == 'BRCA1']

# %%
len(wt_ng_cbe)
# Out:
# 525

# %%
#drop noncoding guides
wt_ng_cbe_coding = wt_ng_cbe[wt_ng_cbe['Mutation bin_x']!='Intron']
wt_ng_cbe_coding = wt_ng_cbe_coding[wt_ng_cbe_coding['Mutation bin_x']!= 'UTR']

# %%
len(wt_ng_cbe_coding)
# Out:
# 459

# %%
color_dictionary = dict({'No edits':'#8da0cb',
                  'Silent': '#8da0cb',
                  'Missense': '#e78ac3',
                  'Splice site': '#a6d854',
                  'Nonsense': '#ffd92f'})

# %%
sns.set(rc={'figure.figsize':(2,2)})
gpp.set_aesthetics(context='paper', palette='Set2')
ax= sns.scatterplot(x='AvgHAP1_Meljuso;z-score;NG-CBE', y='AvgHAP1_Meljuso;z-score;WT-CBE',
               data = wt_ng_cbe_coding, hue='Mutation bin_x', palette=color_dictionary,linewidth=0, legend=False)
gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;NG-CBE', y='AvgHAP1_Meljuso;z-score;WT-CBE',
               data = wt_ng_cbe_coding)

ax.set_xticks([-15,-10,-5,0,5])
ax.set_yticks([-15,-10,-5,0,5])
ax.text(4,-12.75,'n = '+str(len(wt_ng_cbe_coding)), fontsize=8,ha='right',va='bottom')


plt.xlabel('NG-CBE \n z-scored LFC')
plt.ylabel ('WT-CBE \n z-scored LFC')
# plt.axhline(-2, linestyle='dashed', color = 'grey')
# plt.axhline(-4, linestyle='dashed', color = 'grey')
# plt.axvline(-2, linestyle='dashed', color = 'grey')
# plt.axvline(-4, linestyle='dashed', color = 'grey')
plt.xlim(-13,5)
plt.ylim(-13,5)
#ax.legend(facecolor='white', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig('../../Figures/panels/Fig 5/ng cbe vs wt_v4.pdf', bbox_inches='tight', dpi=1000, transparent=True)
# Out:
# (-13.0, 5.0)

# %%
wt_ng_cbe['Construct IDs_x'].value_counts()
# Out:
# BRCA1    525
# Name: Construct IDs_x, dtype: int64

# %%
wt_ng_cbe['Mutation bin_x'].value_counts()
# Out:
# Missense       199
# No edits       144
# Silent          79
# Intron          59
# Nonsense        26
# Splice site     11
# UTR              7
# Name: Mutation bin_x, dtype: int64

# %% [markdown]
# ### SpG vs WT -- CBE

# %%
print(brca_wt_cbe.shape)
brca_wt_cbe.head()
# Out:
# (723, 38)
#       Construct Barcode                          Construct IDs  \
# 0  TTCATTGGAACAGAAAGAAA            TTCATTGGAACAGAAAGAAA;BRCA1;
# 1  AAATCTTAGAGTGTCCCATC       AAATCTTAGAGTGTCCCATC;BRCA1;I21I;
# 2  CTTGTGCTGACTTACCAGAT   CTTGTGCTGACTTACCAGAT;BRCA1;Exon2:+9;
# 3  TCTTGTGCTGACTTACCAGA   TCTTGTGCTGACTTACCAGA;BRCA1;Exon2:+9;
# 4  AGCACAAGAGTGTATTAATT  AGCACAAGAGTGTATTAATT;BRCA1;Exon2:+12;
#
#    HAP1_Dropout_RepA  HAP1_Dropout_RepB  HAP1_Dropout_RepC  \
# 0          -0.950986          -0.884010          -0.818571
# 1           0.348789           0.287101           0.185596
# 2           0.190411           0.140385           0.296765
# 3          -0.196196          -0.306559          -0.227523
# 4           0.540360           0.505754           0.521858
#
#    Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  Meljuso_Dropout_RepC  \
# 0             -0.885524             -0.848881             -0.856270
# 1              0.336294              0.207309              0.109502
# 2             -0.703793             -0.265804             -0.677387
# 3             -2.333888             -2.474497             -1.926979
# 4              0.397165              0.281295              0.384297
#
#    Meljuso_Cisplatin_RepA  Meljuso_Cisplatin_RepB  ...  # silent edits  \
# 0               -0.962905               -0.881408  ...             0.0
# 1                0.250728                0.104310  ...             1.0
# 2                0.094742                0.028039  ...             0.0
# 3               -0.660860               -0.628593  ...             0.0
# 4                0.338703                0.348768  ...             0.0
#
#    Nucleotide edits  Amino acid edits  Mutation category  \
# 0               NaN               NaN                NaN
# 1              C_5;         Ile21Ile;            Silent;
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4              C_5;        Exon2:+12;            Intron;
#
#    Clinical significance Match Bin I counts AvgHAP1_Meljuso;z-score;WT-CBE  \
# 0                    NaN                  1                      -3.287739
# 1          Likely benign                  0                       0.178913
# 2                    NaN                  0                      -0.158507
# 3                    NaN                  0                      -1.806541
# 4                   None                  1                       0.759998
#
#   Mutation bin Residues Median Residues
# 0     No edits      NaN             NaN
# 1       Silent      21;            21.0
# 2     No edits      NaN             NaN
# 3     No edits      NaN             NaN
# 4       Intron  intron;             NaN
#
# [5 rows x 38 columns]

# %%
spg_cbe = pd.read_csv('../../data_v3/Fig 5_6_BRCA1/processed/BRCA1-SpG-CBE_LFC_v2.csv')

# %%
print(spg_cbe.shape)
spg_cbe.head()
# Out:
# (11635, 40)
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  CTGTTCCAATGAACTTTAAC         BRCA1          -0.678967          -0.307261
# 1  ATGTGTTAAAGTTCATTGGA         BRCA1          -0.127355           0.166564
# 2  TCTGTTCCAATGAACTTTAA         BRCA1          -0.463288          -0.675417
# 3  TGTGTTAAAGTTCATTGGAA         BRCA1           0.038987           0.021819
# 4  TTCTGTTCCAATGAACTTTA         BRCA1          -0.325489          -0.304338
#
#    Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  Meljuso_Cisplatin_RepA  \
# 0             -0.715497             -0.876816               -0.574603
# 1             -0.000371              0.094519                0.267944
# 2             -0.431660             -0.397524               -0.423830
# 3              0.150096              0.159416                0.111368
# 4             -0.369750             -0.470117               -0.437012
#
#    Meljuso_Cisplatin_RepB  HAP1_Dropout_RepAB  Meljuso_Dropout_RepAB  ...  \
# 0               -0.920235           -0.493114              -0.796157  ...
# 1                0.059226            0.019604               0.047074  ...
# 2               -0.635142           -0.569352              -0.414592  ...
# 3                0.119225            0.030403               0.154756  ...
# 4               -0.426546           -0.314914              -0.419934  ...
#
#    Nucleotide edits  Amino acid edits Mutation category  \
# 0          C_6;C_7;          utr;utr;          UTR;UTR;
# 1               NaN               NaN               NaN
# 2          C_7;C_8;          utr;utr;          UTR;UTR;
# 3               NaN               NaN               NaN
# 4              C_8;              utr;              UTR;
#
#          Clinical significance BsmBI flag 4T flag AvgHAP1_Meljuso;z-score  \
# 0  None;Uncertain significance        NaN     NaN               -6.571863
# 1                          NaN        NaN     NaN               -1.023451
# 2  Uncertain significance;None        NaN     NaN               -6.019663
# 3                          NaN        NaN     NaN               -1.169553
# 4                         None        NaN     NaN               -4.647310
#
#    Mutation bin  Residues Median Residues
# 0           UTR  utr;utr;             NaN
# 1      No edits       NaN             NaN
# 2           UTR  utr;utr;             NaN
# 3      No edits       NaN             NaN
# 4           UTR      utr;             NaN
#
# [5 rows x 40 columns]

# %%
#rename spg

spg_cbe = spg_cbe.rename(columns={'AvgHAP1_Meljuso;z-score': 'AvgHAP1_Meljuso;z-score;SpG-CBE'})

# %%
#merge on shared guides targeting BRCA1

wt_spg_cbe = pd.merge(brca_wt_cbe, spg_cbe, on = 'Construct Barcode',how = 'inner')

# %%
wt_spg_cbe = wt_spg_cbe[wt_spg_cbe['Construct IDs_y'] == 'BRCA1']

# %%
wt_spg_cbe_coding = wt_spg_cbe[wt_spg_cbe['Mutation bin_y']!='Intron']
wt_spg_cbe_coding = wt_spg_cbe_coding[wt_spg_cbe_coding['Mutation bin_y']!= 'UTR']

# %%
print(wt_spg_cbe_coding.shape)
wt_spg_cbe_coding.head()
# Out:
# (459, 77)
#       Construct Barcode                            Construct IDs_x  \
# 0  AAATCTTAGAGTGTCCCATC           AAATCTTAGAGTGTCCCATC;BRCA1;I21I;
# 4  CCAGACTAGCAGGGTAGGGG       CCAGACTAGCAGGGTAGGGG;BRCA1;Exon3:-1;
# 5  TCCAGACTAGCAGGGTAGGG       TCCAGACTAGCAGGGTAGGG;BRCA1;Exon3:-1;
# 6  CTCCAGACTAGCAGGGTAGG  CTCCAGACTAGCAGGGTAGG;BRCA1;L28L;Exon3:-1;
# 7  ACTCCAGACTAGCAGGGTAG      ACTCCAGACTAGCAGGGTAG;BRCA1;E29K;L28L;
#
#    HAP1_Dropout_RepA_x  HAP1_Dropout_RepB_x  HAP1_Dropout_RepC  \
# 0             0.348789             0.287101           0.185596
# 4            -3.123345            -3.216919          -3.610941
# 5            -2.412283            -2.342102          -2.253729
# 6            -0.696691            -0.529950          -0.622318
# 7            -0.195325            -0.049541          -0.016768
#
#    Meljuso_Dropout_RepA_x  Meljuso_Dropout_RepB_x  Meljuso_Dropout_RepC  \
# 0                0.336294                0.207309              0.109502
# 4               -1.284515               -1.651670             -1.468709
# 5               -0.973591               -1.258844             -1.231295
# 6                0.314960                0.220615              0.320277
# 7                0.391230                0.336281              0.160227
#
#    Meljuso_Cisplatin_RepA_x  Meljuso_Cisplatin_RepB_x  ...  \
# 0                  0.250728                  0.104310  ...
# 4                 -2.018091                 -1.570603  ...
# 5                 -1.381554                 -1.110568  ...
# 6                 -0.677398                 -0.306429  ...
# 7                 -0.614949                 -0.633144  ...
#
#    Nucleotide edits_y  Amino acid edits_y      Mutation category_y  \
# 0                C_5;           Ile21Ile;                  Silent;
# 4                C_6;           Exon3:-1;         Splice-acceptor;
# 5                C_7;           Exon3:-1;         Splice-acceptor;
# 6            C_4;C_8;  Leu28Leu;Exon3:-1;  Silent;Splice-acceptor;
# 7            C_4;C_5;  Glu29Lys;Leu28Leu;         Missense;Silent;
#
#                              Clinical significance_y  BsmBI flag 4T flag  \
# 0                                      Likely benign         NaN     NaN
# 4                       Pathogenic/Likely pathogenic         NaN     NaN
# 5                       Pathogenic/Likely pathogenic         NaN     NaN
# 6  Pathogenic/Likely pathogenic;Uncertain signifi...         NaN     NaN
# 7                        None;Uncertain significance         NaN     NaN
#
#   AvgHAP1_Meljuso;z-score;SpG-CBE Mutation bin_y  Residues_y Median Residues_y
# 0                       -0.991746         Silent         21;              21.0
# 4                       -6.899247    Splice site     intron;               NaN
# 5                       -6.005795    Splice site     intron;               NaN
# 6                       -2.224105    Splice site  28;intron;               NaN
# 7                       -0.610708       Missense      29;28;              28.5
#
# [5 rows x 77 columns]

# %%
gpp.set_aesthetics(context='paper')
ax= sns.scatterplot(x='AvgHAP1_Meljuso;z-score;SpG-CBE', y='AvgHAP1_Meljuso;z-score;WT-CBE',
               data = wt_spg_cbe_coding, hue='Mutation bin_y', palette= color_dictionary, linewidth=0, legend=False)

gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;SpG-CBE', y='AvgHAP1_Meljuso;z-score;WT-CBE',
               data = wt_spg_cbe_coding)
sns.set(rc={'figure.figsize':(2,2)})
plt.xlabel('SpG-CBE \n Avg Z-scored LFC')
plt.ylabel ('')

ax.set_xticks([-15,-10,-5,0,5])
ax.set_yticks([-15,-10,-5,0,5])

ax.text(4,-12.75,'n = '+str(len(wt_spg_cbe_coding)), fontsize=8,ha='right',va='bottom')


plt.xlim(-13,5)
plt.ylim(-13,5)
#ax.legend(facecolor='white', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig('../../Figures/panels/Fig 5/spg cbe vs wt_v2.pdf', bbox_inches='tight', dpi=1000, transparent=True)
# Out:
# (-13.0, 5.0)

# %% [markdown]
# # ABEs

# %% [markdown]
# WT vs. NG

# %%
wt_abe = pd.read_csv('../../data_v3/Fig 5_6_BRCA1/processed/BRCA1-WT-ABE8e_LFC.csv')

# %%
print(wt_abe.shape)
wt_abe.head()
# Out:
# (723, 44)
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  TTCATTGGAACAGAAAGAAA         BRCA1          -2.175275          -1.763892
# 1  AAATCTTAGAGTGTCCCATC         BRCA1           0.127530           0.415294
# 2  CTTGTGCTGACTTACCAGAT         BRCA1           0.589022           0.028098
# 3  TCTTGTGCTGACTTACCAGA         BRCA1          -1.526309          -1.474756
# 4  AGCACAAGAGTGTATTAATT         BRCA1          -0.307220          -0.647536
#
#    HAP1_Dropout_RepC  Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  \
# 0          -1.982709             -1.376859             -1.814091
# 1           0.438687              0.352026              0.189607
# 2           0.526519              0.630486              0.833777
# 3          -1.230448             -0.995462             -0.929363
# 4          -0.370546             -0.265478             -0.591909
#
#    Meljuso_Dropout_RepC  Meljuso_Cisplatin_RepA  Meljuso_Cisplatin_RepB  ...  \
# 0             -1.210669               -1.797236               -1.669758  ...
# 1              0.522885                0.366971                0.488086  ...
# 2              0.630715                0.004752               -0.171441  ...
# 3             -1.403055               -1.603283               -0.840253  ...
# 4             -0.698018               -0.514317               -0.655819  ...
#
#                  Amino acid edits      Mutation category  \
# 0                            utr;                   UTR;
# 1                       Leu22Leu;                Silent;
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4  Exon2:+11;Exon2:+13;Exon2:+14;  Intron;Intron;Intron;
#
#                           Clinical significance  BsmBI flag  4T flag  \
# 0  Conflicting interpretations of pathogenicity         NaN      NaN
# 1                                 Likely benign         NaN      NaN
# 2                                           NaN         NaN      NaN
# 3                                           NaN         NaN      NaN
# 4                       Likely benign;None;None         NaN      NaN
#
#   Match Bin I counts AvgHAP1_Meljuso;z-score Mutation bin  \
# 0                  1               -3.106649          UTR
# 1                  0                0.751902       Silent
# 2                  0                0.307540     No edits
# 3                  0               -2.426034     No edits
# 4                  1               -0.897320       Intron
#
#                 Residues Median Residues
# 0                   utr;             NaN
# 1                    22;            22.0
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4  intron;intron;intron;             NaN
#
# [5 rows x 44 columns]

# %%
ng_abe = pd.read_csv('../../data_v3/Fig 5_6_BRCA1/processed/BRCA1-NG-ABE8e_LFC.csv')

# %%
#change column names for merge
wt_abe = wt_abe.rename(columns={'AvgHAP1_Meljuso;z-score' : 'AvgHAP1_Meljuso;z-score;WT-ABE'})
ng_abe = ng_abe.rename(columns={'AvgHAP1_Meljuso;z-score' : 'AvgHAP1_Meljuso;z-score;NG-ABE'})

# %%
#merge on shared sgRNAs between wt and ng

both_abe = pd.merge(ng_abe, wt_abe, on= 'Construct Barcode', how='inner')

# %%
gpp.set_aesthetics(context='paper', palette='Set2')

# %%
both_abe_noctrl = both_abe[both_abe['Construct IDs_x'] == 'BRCA1']

# %%
print(both_abe_noctrl.shape)
# Out:
# (525, 83)

# %%
#drop noncoding sgRNAs

both_abe_noctrl_coding = both_abe_noctrl[both_abe_noctrl['Mutation bin_x'] != 'UTR']
both_abe_noctrl_coding = both_abe_noctrl_coding[both_abe_noctrl_coding['Mutation bin_x'] != 'Intron']

# %%
# #color_dictionary = dict({'No edits':'#8da0cb',
#                   'Silent': '#8da0cb',
#                   'Missense': '#e78ac3',
#                   'Splice site': '#ffd92f',
#                   'Nonsense': '#a6d854'})

# %%
gpp.set_aesthetics(context='paper')
ax= sns.scatterplot(x='AvgHAP1_Meljuso;z-score;NG-ABE', y='AvgHAP1_Meljuso;z-score;WT-ABE',
               data = both_abe_noctrl_coding, hue='Mutation bin_x', palette= color_dictionary, linewidth=0, legend=False)

gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;NG-ABE', y='AvgHAP1_Meljuso;z-score;WT-ABE',
               data = both_abe_noctrl_coding)
sns.set(rc={'figure.figsize':(2,2)})
plt.xlabel('NG-ABE \n Avg Z-scored LFC')
plt.ylabel ('WT-ABE \n Avg Z-scored LFC')

ax.text(4,-12.75,'n = '+str(len(both_abe_noctrl_coding)), fontsize=8,ha='right',va='bottom')
ax.set_xticks([-15,-10,-5,0,5])
ax.set_yticks([-15,-10,-5,0,5])

plt.xlim(-13,5)
plt.ylim(-13,5)
#ax.legend(facecolor='white', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig('../../Figures/panels/Fig 5/ng abe vs wt_v2.pdf', bbox_inches='tight', dpi=1000, transparent=True)
# Out:
# (-13.0, 5.0)

# %%
len(both_abe_noctrl)
# Out:
# 525

# %% [markdown]
# Calculate shared hits with NG-ABE vs WT-ABE

# %% [markdown]
# ### WT ABE vs SpG ABE

# %%
spg_abe = pd.read_csv('../../data_v3/Fig 5_6_BRCA1/processed/BRCA1-SpG-ABE8e_LFC_v2.csv')

# %%
spg_abe = spg_abe.rename(columns={'AvgHAP1_Meljuso;z-score' : 'AvgHAP1_Meljuso;z-score;SpG-ABE'})

# %%
wt_abe.head()
# Out:
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  TTCATTGGAACAGAAAGAAA         BRCA1          -2.175275          -1.763892
# 1  AAATCTTAGAGTGTCCCATC         BRCA1           0.127530           0.415294
# 2  CTTGTGCTGACTTACCAGAT         BRCA1           0.589022           0.028098
# 3  TCTTGTGCTGACTTACCAGA         BRCA1          -1.526309          -1.474756
# 4  AGCACAAGAGTGTATTAATT         BRCA1          -0.307220          -0.647536
#
#    HAP1_Dropout_RepC  Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  \
# 0          -1.982709             -1.376859             -1.814091
# 1           0.438687              0.352026              0.189607
# 2           0.526519              0.630486              0.833777
# 3          -1.230448             -0.995462             -0.929363
# 4          -0.370546             -0.265478             -0.591909
#
#    Meljuso_Dropout_RepC  Meljuso_Cisplatin_RepA  Meljuso_Cisplatin_RepB  ...  \
# 0             -1.210669               -1.797236               -1.669758  ...
# 1              0.522885                0.366971                0.488086  ...
# 2              0.630715                0.004752               -0.171441  ...
# 3             -1.403055               -1.603283               -0.840253  ...
# 4             -0.698018               -0.514317               -0.655819  ...
#
#                  Amino acid edits      Mutation category  \
# 0                            utr;                   UTR;
# 1                       Leu22Leu;                Silent;
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4  Exon2:+11;Exon2:+13;Exon2:+14;  Intron;Intron;Intron;
#
#                           Clinical significance  BsmBI flag  4T flag  \
# 0  Conflicting interpretations of pathogenicity         NaN      NaN
# 1                                 Likely benign         NaN      NaN
# 2                                           NaN         NaN      NaN
# 3                                           NaN         NaN      NaN
# 4                       Likely benign;None;None         NaN      NaN
#
#   Match Bin I counts AvgHAP1_Meljuso;z-score;WT-ABE Mutation bin  \
# 0                  1                      -3.106649          UTR
# 1                  0                       0.751902       Silent
# 2                  0                       0.307540     No edits
# 3                  0                      -2.426034     No edits
# 4                  1                      -0.897320       Intron
#
#                 Residues Median Residues
# 0                   utr;             NaN
# 1                    22;            22.0
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4  intron;intron;intron;             NaN
#
# [5 rows x 44 columns]

# %%
#merge on shared sgRNAs between wt and ng

both_abe_spg = pd.merge(spg_abe, wt_abe, on= 'Construct Barcode', how='inner')

# %%
#only look at guides targeting BRCA1
both_abe_spg_brca1 = both_abe_spg[both_abe_spg['Construct IDs_x'] == 'BRCA1']
print(both_abe_spg_brca1.shape)
# Out:
# (529, 83)

# %%
#drop noncoding sgRNAs

both_abe_spg_brca1_coding = both_abe_spg_brca1[both_abe_spg_brca1['Mutation bin_x'] != 'UTR']
both_abe_spg_brca1_coding = both_abe_spg_brca1_coding[both_abe_spg_brca1_coding['Mutation bin_x'] != 'Intron']

# %%
gpp.set_aesthetics(context='paper')
ax= sns.scatterplot(x='AvgHAP1_Meljuso;z-score;SpG-ABE', y='AvgHAP1_Meljuso;z-score;WT-ABE',
               data = both_abe_spg_brca1_coding, hue='Mutation bin_x', palette= color_dictionary, linewidth=0, legend=False)

gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;SpG-ABE', y='AvgHAP1_Meljuso;z-score;WT-ABE',
               data = both_abe_spg_brca1_coding)
sns.set(rc={'figure.figsize':(2,2)})
plt.xlabel('SpG-ABE \n Avg Z-scored LFC')
plt.ylabel ('')

ax.text(4,-12.75,'n = '+str(len(both_abe_spg_brca1_coding)), fontsize=8,ha='right',va='bottom')
ax.set_xticks([-15,-10,-5,0,5])
ax.set_yticks([-15,-10,-5,0,5])

plt.xlim(-13,5)
plt.ylim(-13,5)
#ax.legend(facecolor='white', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig('../../Figures/panels/Fig 5/spg abe vs wt_v2.pdf', bbox_inches='tight', dpi=1000, transparent=True)
# Out:
# (-13.0, 5.0)

# %% [markdown]
# # NG CBE vs ABE

# %%
ng_abe.head()
# Out:
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  CTGTTCCAATGAACTTTAAC         BRCA1          -0.315877          -2.192888
# 1  ATGTGTTAAAGTTCATTGGA         BRCA1           0.356418           0.329725
# 2  TCTGTTCCAATGAACTTTAA         BRCA1          -0.994517          -0.327970
# 3  TGTGTTAAAGTTCATTGGAA         BRCA1          -0.119882          -0.132349
# 4  TTCTGTTCCAATGAACTTTA         BRCA1          -0.050652          -0.560736
#
#    Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  Meljuso_Cisplatin_RepA  \
# 0             -1.148451             -0.892693               -1.651345
# 1              0.319577              0.681756                0.430183
# 2             -0.269479             -0.792946               -0.979590
# 3             -0.359733             -0.124764               -0.054230
# 4             -0.918586             -0.438380               -0.734778
#
#    Meljuso_Cisplatin_RepB  HAP1_Dropout_RepAB  Meljuso_Dropout_RepAB  ...  \
# 0               -0.922185           -1.254383              -1.020572  ...
# 1                0.521918            0.343072               0.500667  ...
# 2               -0.607706           -0.661243              -0.531212  ...
# 3               -0.155708           -0.126115              -0.242248  ...
# 4               -0.609723           -0.305694              -0.678483  ...
#
#    Nucleotide edits      Amino acid edits Mutation category  \
# 0              A_8;                  utr;              UTR;
# 1              A_8;            Exon2:-23;           Intron;
# 2               NaN                   NaN               NaN
# 3          A_7;A_8;  Exon2:-23;Exon2:-22;    Intron;Intron;
# 4               NaN                   NaN               NaN
#
#                                Clinical significance BsmBI flag 4T flag  \
# 0                             Uncertain significance        NaN     NaN
# 1                                               None        NaN     NaN
# 2                                                NaN        NaN     NaN
# 3  None;Conflicting interpretations of pathogenicity        NaN     NaN
# 4                                                NaN        NaN     NaN
#
#   AvgHAP1_Meljuso;z-score;NG-ABE  Mutation bin        Residues Median Residues
# 0                      -4.703155           UTR            utr;             NaN
# 1                       0.029920        Intron         intron;             NaN
# 2                      -3.173119      No edits             NaN             NaN
# 3                      -1.449339        Intron  intron;intron;             NaN
# 4                      -2.501322      No edits             NaN             NaN
#
# [5 rows x 40 columns]

# %%
brca1_ng_cbe.head()
# Out:
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  CTGTTCCAATGAACTTTAAC         BRCA1          -0.778097          -1.102872
# 1  ATGTGTTAAAGTTCATTGGA         BRCA1          -0.060195           0.126319
# 2  TCTGTTCCAATGAACTTTAA         BRCA1          -0.579206          -0.268600
# 3  TGTGTTAAAGTTCATTGGAA         BRCA1           0.316748           0.022198
# 4  TTCTGTTCCAATGAACTTTA         BRCA1          -0.408376          -0.247209
#
#    HAP1_Dropout_RepC  Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  \
# 0          -1.243311             -0.832843             -0.715490
# 1           0.332845              0.154970              0.123453
# 2          -0.355417             -0.428716             -0.097972
# 3           0.363735              0.051371             -0.022138
# 4          -0.473564             -0.209041             -0.295195
#
#    Meljuso_Dropout_RepC  Meljuso_Cisplatin_RepA  Meljuso_Cisplatin_RepB  ...  \
# 0             -0.799696               -0.935742               -0.787923  ...
# 1              0.031662                0.157643                0.094979  ...
# 2             -0.470759               -0.365912               -0.347365  ...
# 3             -0.022786                0.055790               -0.048526  ...
# 4             -0.205968               -0.399921               -0.364444  ...
#
#    Nucleotide edits  Amino acid edits  Mutation category  \
# 0          C_6;C_7;          utr;utr;           UTR;UTR;
# 1               NaN               NaN                NaN
# 2          C_7;C_8;          utr;utr;           UTR;UTR;
# 3               NaN               NaN                NaN
# 4              C_8;              utr;               UTR;
#
#          Clinical significance  BsmBI flag 4T flag  \
# 0  None;Uncertain significance         NaN     NaN
# 1                          NaN         NaN     NaN
# 2  Uncertain significance;None         NaN     NaN
# 3                          NaN         NaN     NaN
# 4                         None         NaN     NaN
#
#   AvgHAP1_Meljuso;z-score;NG-CBE Mutation bin  Residues Median Residues
# 0                      -9.051298          UTR  utr;utr;             NaN
# 1                      -0.797852     No edits       NaN             NaN
# 2                      -4.721485          UTR  utr;utr;             NaN
# 3                      -1.027600     No edits       NaN             NaN
# 4                      -4.515973          UTR      utr;             NaN
#
# [5 rows x 43 columns]

# %%
ng_abe = ng_abe.rename(columns={'Mutation bin' : 'ABE Mutation Bin',
                       'Median Residues' : 'ABE Median Residues'})

brca1_ng_cbe = brca1_ng_cbe.rename(columns={'Mutation bin' : 'CBE Mutation Bin',
                       'Median Residues' : 'CBE Median Residues'})

# %%
#merge NG ABE and CBE data

shared_ng = pd.merge(ng_abe, brca1_ng_cbe, on='Construct Barcode', how='inner')

# %%
pamlist4 = pd.read_csv('../../data_v3/pam_lists/2021-05-11_PAM list 4_v2.csv')

# %%
shared_ng_filt = pd.merge(pamlist4, shared_ng, left_on='PAM', right_on='PAM_x',how='inner')

# %%
shared_ng_filt_copy = shared_ng_filt.copy()

# %%
shared_ng_filt_copy['CBE/ABE Mutation Bin'] = shared_ng_filt_copy['CBE Mutation Bin'].astype(str) + "/" + shared_ng_filt_copy['ABE Mutation Bin'].astype(str)

# %%
#No edits and Silent mutations get grouped into "No change"
shared_ng_filt_copy['CBE/ABE Mutation Bin'] = shared_ng_filt_copy['CBE/ABE Mutation Bin'].str.replace('No edits','No change')
shared_ng_filt_copy['CBE/ABE Mutation Bin'] = shared_ng_filt_copy['CBE/ABE Mutation Bin'].str.replace('Silent','No change')

# %%
shared_ng_filt_copy['CBE/ABE Mutation Bin'].value_counts()
# Out:
# No change/Missense         708
# Missense/Missense          530
# Missense/No change         456
# No change/No change        222
# Intron/Intron              126
# Nonsense/Missense          102
# No change/Intron            79
# Intron/No change            52
# Splice site/Intron          16
# Intron/Splice site          13
# Splice site/Splice site     13
# UTR/UTR                     12
# Splice site/Missense        12
# Splice site/No change       11
# Nonsense/No change          10
# No change/Splice site        7
# UTR/No change                6
# Nonsense/Splice site         3
# UTR/Missense                 3
# No change/UTR                3
# Missense/Splice site         1
# Name: CBE/ABE Mutation Bin, dtype: int64

# %%
#filter out other mutation bins
shared_ng_filt_copy = shared_ng_filt_copy[shared_ng_filt_copy['CBE/ABE Mutation Bin'].str.contains("Intron") == False]
shared_ng_filt_copy = shared_ng_filt_copy[shared_ng_filt_copy['CBE/ABE Mutation Bin'].str.contains("UTR") == False]
shared_ng_filt_copy = shared_ng_filt_copy[shared_ng_filt_copy['CBE/ABE Mutation Bin'].str.contains("Nonsense") == False]
shared_ng_filt_copy = shared_ng_filt_copy[shared_ng_filt_copy['CBE/ABE Mutation Bin'].str.contains("Splice site") == False]
shared_ng_filt_copy = shared_ng_filt_copy[shared_ng_filt_copy['CBE/ABE Mutation Bin'].str.contains("Missense") == True]

# %%
len(shared_ng_filt_copy)
# Out:
# 1694

# %%
#shared_spg_copy.to_csv('shared_spg.csv')

# %%
validation = {#'GTCACCCCTAAAGAGATCAT' : 'sg1',
    'AGGAACCTGTCTCCACAAAG':  'sg2',
    'ATTCCTAGAAAATATTTCAG' : 'sg9',
    'GAAACCACCAAGGTCCAAAG' : 'sg10',
    'GAACATCTTCAGTATCTCTA' : 'sg11',
    'TATTTCACCATCATCTAACA' : 'sg12',
    #'GCTAACTTCCAGTAACGAGA' : 'sg13',
    #'TATATCATTCTTACATAAAG' : 'sg14',
    'TTACATAAAGGACACTGTGA' : 'sg15',
    #'TATCCACAATTCAAAAGCAC' : 'sg16',
    #'TAACCACTCAGGTAAAAAGC' : 'sg17',
    #'TCATCAACCCAGTAATAATG' : 'sg18',
    #'TTCTACCAGTAAAAATAAAG' : 'sg19'
    
}

# %%
ax= sns.scatterplot(x='AvgHAP1_Meljuso;z-score;NG-CBE', y='AvgHAP1_Meljuso;z-score;NG-ABE',
               data = shared_ng_filt_copy, color = "#e78ac3", linewidth=0, alpha=0.7)

gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;NG-CBE', y='AvgHAP1_Meljuso;z-score;NG-ABE',
               data = shared_ng_filt_copy)
sns.set(rc={'figure.figsize':(1.7,1.7)})
sns.set_style("white")
plt.xlabel('NG-CBE\n Avg Z-scored LFC ')
plt.ylabel ('NG-ABE\n Avg Z-scored LFC ')


#if label_points != {}:
for k in validation.keys():
    name = validation[k]
    x = shared_ng_filt_copy.loc[shared_ng_filt_copy['Construct Barcode'] == k,'AvgHAP1_Meljuso;z-score;NG-CBE'].item()
    y = shared_ng_filt_copy.loc[shared_ng_filt_copy['Construct Barcode'] == k,'AvgHAP1_Meljuso;z-score;NG-ABE'].item()
    #c = color_dict[shared_ng_filtered.loc[shared_ng_filtered['Construct Barcode'] == k,'Mutation bin'].item()]
    if ~np.isnan(x):
        ax.plot([x,x+.5], [y,y+.5],c='black',zorder=4,linewidth=.5)
        ax.text(x+.6,y+.6,name,fontsize=7)
        ax.scatter(x,y,s=30,color = "#a6d854",zorder=3,linewidths=0.1,
                    edgecolors='#a6d854')
plt.xlim(-19,5)
plt.ylim(-19,5)
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('../../Figures/panels/Fig 5/ng cbe vs abe.pdf',bbox_inches='tight', dpi=1000, transparent=True)

# %%
len(shared_ng_filt_copy)
# Out:
# 1694

# %%
darks = dict({'Missense/No change':'#d9d9d9',
                  'No change/Missense':'#969696',
                  'Missense/Missense': '#e78ac3',})

# %%
gpp.set_aesthetics(context='paper')
ax= sns.scatterplot(x='AvgHAP1_Meljuso;z-score;NG-CBE', y='AvgHAP1_Meljuso;z-score;NG-ABE',
               data = shared_ng_filt_copy, hue='CBE/ABE Mutation Bin', palette= darks, linewidth=0)

gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;NG-CBE', y='AvgHAP1_Meljuso;z-score;NG-ABE',
               data = shared_ng_filt_copy)
sns.set(rc={'figure.figsize':(3,3)})
sns.set_style("white")
plt.xlabel('NG-CBE\n Avg Z-scored LFC ')
plt.ylabel ('NG-ABE\n Avg Z-scored LFC ')

ax.text(4,-18,'n = '+str(len(shared_ng_filt_copy)), fontsize=8,ha='right',va='bottom')
ax.set_xticks([-15,-10,-5,0,5])
ax.set_yticks([-15,-10,-5,0,5])


plt.xlim(-19,5)
plt.ylim(-19,5)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.savefig('../../Figures/panels/Fig 5/ng cbe vs abe.pdf',bbox_inches='tight', dpi=1000, transparent=True)

# %%
gpp.set_aesthetics(context='paper')
ax= gpp.point_densityplot(x='AvgHAP1_Meljuso;z-score;NG-CBE', y='AvgHAP1_Meljuso;z-score;NG-ABE',
               data = shared_ng_filt_copy)

gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;NG-CBE', y='AvgHAP1_Meljuso;z-score;NG-ABE',
               data = shared_ng_filt_copy)
sns.set(rc={'figure.figsize':(3,3)})
sns.set_style("white")
plt.xlabel('NG-CBE\n Avg Z-scored LFC ')
plt.ylabel ('NG-ABE\n Avg Z-scored LFC ')

ax.text(4,-18,'n = '+str(len(shared_ng_filt_copy)), fontsize=8,ha='right',va='bottom')
ax.set_xticks([-15,-10,-5,0,5])
ax.set_yticks([-15,-10,-5,0,5])


plt.xlim(-19,5)
plt.ylim(-19,5)
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('../../Figures/panels/Fig 5/ng cbe vs abe.pdf',bbox_inches='tight', dpi=1000, transparent=True)
# Out:
# (-19.0, 5.0)

# %%
# shared_ng = pd.merge(brca1_ng_cbe, ng_abe, on = ['Construct Barcode', 'Construct IDs'], how= 'inner')

# %%
# shared_ng

# %% [markdown]
# # SpG ABE vs CBE

# %%
print(spg_abe.shape)
spg_abe.head()
# Out:
# (11636, 40)
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  CTGTTCCAATGAACTTTAAC         BRCA1          -1.027664          -1.067850
# 1  ATGTGTTAAAGTTCATTGGA         BRCA1           0.293575           0.306401
# 2  TCTGTTCCAATGAACTTTAA         BRCA1          -1.292662          -0.898147
# 3  TGTGTTAAAGTTCATTGGAA         BRCA1          -0.255978           0.052712
# 4  TTCTGTTCCAATGAACTTTA         BRCA1          -0.736338          -0.695255
#
#    Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  Meljuso_Cisplatin_RepA  \
# 0             -1.136378             -1.374668               -1.014842
# 1              0.504665              0.436246                0.416634
# 2             -1.171610             -1.392799               -1.303491
# 3             -0.069727             -0.190655                0.003339
# 4             -0.818269             -0.711520               -0.503065
#
#    Meljuso_Cisplatin_RepB  HAP1_Dropout_RepAB  Meljuso_Dropout_RepAB  ...  \
# 0               -1.560168           -1.047757              -1.255523  ...
# 1                0.370474            0.299988               0.470456  ...
# 2               -0.753309           -1.095405              -1.282204  ...
# 3               -0.189906           -0.101633              -0.130191  ...
# 4               -0.778934           -0.715797              -0.764895  ...
#
#    Nucleotide edits      Amino acid edits Mutation category  \
# 0              A_8;                  utr;              UTR;
# 1              A_8;            Exon2:-23;           Intron;
# 2               NaN                   NaN               NaN
# 3          A_7;A_8;  Exon2:-23;Exon2:-22;    Intron;Intron;
# 4               NaN                   NaN               NaN
#
#                                Clinical significance BsmBI flag 4T flag  \
# 0                             Uncertain significance        NaN     NaN
# 1                                               None        NaN     NaN
# 2                                                NaN        NaN     NaN
# 3  None;Conflicting interpretations of pathogenicity        NaN     NaN
# 4                                                NaN        NaN     NaN
#
#   AvgHAP1_Meljuso;z-score;SpG-ABE  Mutation bin        Residues  \
# 0                       -5.369067           UTR            utr;
# 1                       -0.443774        Intron         intron;
# 2                       -5.025205      No edits             NaN
# 3                       -1.888542        Intron  intron;intron;
# 4                       -3.777933      No edits             NaN
#
#   Median Residues
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 40 columns]

# %%
spg_abe = spg_abe.rename(columns={'Mutation bin' : 'ABE Mutation Bin',
                       'Median Residues' : 'ABE Median Residues'})

# %%
print(spg_cbe.shape)
spg_cbe.head()
# Out:
# (11635, 40)
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  CTGTTCCAATGAACTTTAAC         BRCA1          -0.678967          -0.307261
# 1  ATGTGTTAAAGTTCATTGGA         BRCA1          -0.127355           0.166564
# 2  TCTGTTCCAATGAACTTTAA         BRCA1          -0.463288          -0.675417
# 3  TGTGTTAAAGTTCATTGGAA         BRCA1           0.038987           0.021819
# 4  TTCTGTTCCAATGAACTTTA         BRCA1          -0.325489          -0.304338
#
#    Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  Meljuso_Cisplatin_RepA  \
# 0             -0.715497             -0.876816               -0.574603
# 1             -0.000371              0.094519                0.267944
# 2             -0.431660             -0.397524               -0.423830
# 3              0.150096              0.159416                0.111368
# 4             -0.369750             -0.470117               -0.437012
#
#    Meljuso_Cisplatin_RepB  HAP1_Dropout_RepAB  Meljuso_Dropout_RepAB  ...  \
# 0               -0.920235           -0.493114              -0.796157  ...
# 1                0.059226            0.019604               0.047074  ...
# 2               -0.635142           -0.569352              -0.414592  ...
# 3                0.119225            0.030403               0.154756  ...
# 4               -0.426546           -0.314914              -0.419934  ...
#
#    Nucleotide edits  Amino acid edits Mutation category  \
# 0          C_6;C_7;          utr;utr;          UTR;UTR;
# 1               NaN               NaN               NaN
# 2          C_7;C_8;          utr;utr;          UTR;UTR;
# 3               NaN               NaN               NaN
# 4              C_8;              utr;              UTR;
#
#          Clinical significance BsmBI flag 4T flag  \
# 0  None;Uncertain significance        NaN     NaN
# 1                          NaN        NaN     NaN
# 2  Uncertain significance;None        NaN     NaN
# 3                          NaN        NaN     NaN
# 4                         None        NaN     NaN
#
#   AvgHAP1_Meljuso;z-score;SpG-CBE  CBE Mutation Bin  Residues  \
# 0                       -6.571863               UTR  utr;utr;
# 1                       -1.023451          No edits       NaN
# 2                       -6.019663               UTR  utr;utr;
# 3                       -1.169553          No edits       NaN
# 4                       -4.647310               UTR      utr;
#
#   CBE Median Residues
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 40 columns]

# %%
spg_cbe = spg_cbe.rename(columns={'Mutation bin' : 'CBE Mutation Bin',
                       'Median Residues' : 'CBE Median Residues'})

# %%
#merge SpG ABE and CBE data

shared_spg = pd.merge(spg_abe, spg_cbe, on='Construct Barcode', how='inner')

# %%
#filter on intermediate/active pams with pam list 4

shared_spg_filt = pd.merge(shared_spg, pamlist4, left_on= 'PAM_y', right_on='PAM', how='inner')

# %%
shared_spg_copy = shared_spg_filt.copy()

# %%
shared_spg_copy['CBE/ABE Mutation Bin'] = shared_spg_copy['CBE Mutation Bin'].astype(str) + "/" + shared_spg_copy['ABE Mutation Bin'].astype(str)

# %%
#No edits and Silent mutations get grouped into "No change"
shared_spg_copy['CBE/ABE Mutation Bin'] = shared_spg_copy['CBE/ABE Mutation Bin'].str.replace('No edits','No change')
shared_spg_copy['CBE/ABE Mutation Bin'] = shared_spg_copy['CBE/ABE Mutation Bin'].str.replace('Silent','No change')

# %%
shared_spg_copy['CBE/ABE Mutation Bin'].value_counts()
# Out:
# No change/Missense         707
# Missense/Missense          527
# Missense/No change         453
# No change/No change        221
# Intron/Intron              127
# Nonsense/Missense          103
# No change/Intron            80
# Intron/No change            51
# Splice site/Intron          16
# Splice site/Splice site     14
# Intron/Splice site          13
# UTR/UTR                     12
# Splice site/Missense        12
# Splice site/No change       11
# Nonsense/No change          10
# No change/Splice site        7
# UTR/No change                6
# UTR/Missense                 3
# No change/UTR                3
# Nonsense/Splice site         3
# Missense/Splice site         1
# Name: CBE/ABE Mutation Bin, dtype: int64

# %%
#filter out other mutation bins
shared_spg_copy = shared_spg_copy[shared_spg_copy['CBE/ABE Mutation Bin'].str.contains("Intron") == False]
shared_spg_copy = shared_spg_copy[shared_spg_copy['CBE/ABE Mutation Bin'].str.contains("UTR") == False]
shared_spg_copy = shared_spg_copy[shared_spg_copy['CBE/ABE Mutation Bin'].str.contains("Nonsense") == False]
shared_spg_copy = shared_spg_copy[shared_spg_copy['CBE/ABE Mutation Bin'].str.contains("Splice site") == False]
shared_spg_copy = shared_spg_copy[shared_spg_copy['CBE/ABE Mutation Bin'].str.contains("Missense") == True]

# %%
len(shared_spg_copy)
# Out:
# 1687

# %%
shared_spg_copy.to_csv('shared_spg.csv')

# %%
darks = dict({'Missense/No change':'#d9d9d9',
                  'No change/Missense':'#969696',
                  'Missense/Missense': '#e78ac3',})

# %%
gpp.set_aesthetics(context='paper')
ax= sns.scatterplot(x='AvgHAP1_Meljuso;z-score;SpG-CBE', y='AvgHAP1_Meljuso;z-score;SpG-ABE',
               data = shared_spg_copy, hue='CBE/ABE Mutation Bin', palette= darks, linewidth=0)

gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;SpG-CBE', y='AvgHAP1_Meljuso;z-score;SpG-ABE',
               data = shared_spg_copy)
sns.set(rc={'figure.figsize':(3,3)})
sns.set_style("white")
plt.xlabel('SpG-CBE\n Avg z-scored LFC from pDNA')
plt.ylabel ('SpG-ABE\n Avg z-scored LFC from pDNA')
plt.axhline(-2, linestyle='dashed', color = 'black')
plt.axhline(-4, linestyle='dashed', color = 'black')
plt.axvline(-2, linestyle='dashed', color = 'black')
plt.axvline(-4, linestyle='dashed', color = 'black')
plt.xlim(-12.5,5)
plt.ylim(-12.5,5)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.savefig('spg cbe vs abe.pdf',bbox_inches='tight', dpi=1000, transparent=True)

# %% [markdown]
# # NG ABE8e vs SpG ABE8e

# %%
ng_abe.head()
# Out:
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  CTGTTCCAATGAACTTTAAC         BRCA1          -0.315877          -2.192888
# 1  ATGTGTTAAAGTTCATTGGA         BRCA1           0.356418           0.329725
# 2  TCTGTTCCAATGAACTTTAA         BRCA1          -0.994517          -0.327970
# 3  TGTGTTAAAGTTCATTGGAA         BRCA1          -0.119882          -0.132349
# 4  TTCTGTTCCAATGAACTTTA         BRCA1          -0.050652          -0.560736
#
#    Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  Meljuso_Cisplatin_RepA  \
# 0             -1.148451             -0.892693               -1.651345
# 1              0.319577              0.681756                0.430183
# 2             -0.269479             -0.792946               -0.979590
# 3             -0.359733             -0.124764               -0.054230
# 4             -0.918586             -0.438380               -0.734778
#
#    Meljuso_Cisplatin_RepB  HAP1_Dropout_RepAB  Meljuso_Dropout_RepAB  ...  \
# 0               -0.922185           -1.254383              -1.020572  ...
# 1                0.521918            0.343072               0.500667  ...
# 2               -0.607706           -0.661243              -0.531212  ...
# 3               -0.155708           -0.126115              -0.242248  ...
# 4               -0.609723           -0.305694              -0.678483  ...
#
#    Nucleotide edits      Amino acid edits Mutation category  \
# 0              A_8;                  utr;              UTR;
# 1              A_8;            Exon2:-23;           Intron;
# 2               NaN                   NaN               NaN
# 3          A_7;A_8;  Exon2:-23;Exon2:-22;    Intron;Intron;
# 4               NaN                   NaN               NaN
#
#                                Clinical significance BsmBI flag 4T flag  \
# 0                             Uncertain significance        NaN     NaN
# 1                                               None        NaN     NaN
# 2                                                NaN        NaN     NaN
# 3  None;Conflicting interpretations of pathogenicity        NaN     NaN
# 4                                                NaN        NaN     NaN
#
#   AvgHAP1_Meljuso;z-score;NG-ABE  ABE Mutation Bin        Residues  \
# 0                      -4.703155               UTR            utr;
# 1                       0.029920            Intron         intron;
# 2                      -3.173119          No edits             NaN
# 3                      -1.449339            Intron  intron;intron;
# 4                      -2.501322          No edits             NaN
#
#   ABE Median Residues
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 40 columns]

# %%
spg_abe.head()
# Out:
#       Construct Barcode Construct IDs  HAP1_Dropout_RepA  HAP1_Dropout_RepB  \
# 0  CTGTTCCAATGAACTTTAAC         BRCA1          -1.027664          -1.067850
# 1  ATGTGTTAAAGTTCATTGGA         BRCA1           0.293575           0.306401
# 2  TCTGTTCCAATGAACTTTAA         BRCA1          -1.292662          -0.898147
# 3  TGTGTTAAAGTTCATTGGAA         BRCA1          -0.255978           0.052712
# 4  TTCTGTTCCAATGAACTTTA         BRCA1          -0.736338          -0.695255
#
#    Meljuso_Dropout_RepA  Meljuso_Dropout_RepB  Meljuso_Cisplatin_RepA  \
# 0             -1.136378             -1.374668               -1.014842
# 1              0.504665              0.436246                0.416634
# 2             -1.171610             -1.392799               -1.303491
# 3             -0.069727             -0.190655                0.003339
# 4             -0.818269             -0.711520               -0.503065
#
#    Meljuso_Cisplatin_RepB  HAP1_Dropout_RepAB  Meljuso_Dropout_RepAB  ...  \
# 0               -1.560168           -1.047757              -1.255523  ...
# 1                0.370474            0.299988               0.470456  ...
# 2               -0.753309           -1.095405              -1.282204  ...
# 3               -0.189906           -0.101633              -0.130191  ...
# 4               -0.778934           -0.715797              -0.764895  ...
#
#    Nucleotide edits      Amino acid edits Mutation category  \
# 0              A_8;                  utr;              UTR;
# 1              A_8;            Exon2:-23;           Intron;
# 2               NaN                   NaN               NaN
# 3          A_7;A_8;  Exon2:-23;Exon2:-22;    Intron;Intron;
# 4               NaN                   NaN               NaN
#
#                                Clinical significance BsmBI flag 4T flag  \
# 0                             Uncertain significance        NaN     NaN
# 1                                               None        NaN     NaN
# 2                                                NaN        NaN     NaN
# 3  None;Conflicting interpretations of pathogenicity        NaN     NaN
# 4                                                NaN        NaN     NaN
#
#   AvgHAP1_Meljuso;z-score;SpG-ABE  ABE Mutation Bin        Residues  \
# 0                       -5.369067               UTR            utr;
# 1                       -0.443774            Intron         intron;
# 2                       -5.025205          No edits             NaN
# 3                       -1.888542            Intron  intron;intron;
# 4                       -3.777933          No edits             NaN
#
#   ABE Median Residues
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 40 columns]

# %%
#filter ng based on PAM list 4
ng_filt = pd.merge(ng_abe, pamlist4, on='PAM', how='inner')
len(ng_filt)
# Out:
# 2389

# %%
pamlist5 = pd.read_csv('../../Data_files/2021-04-06_PAM list 5.csv')

# %%
#filter spg based on PAM list 5
spg_filt = pd.merge(spg_abe, pamlist5, on='PAM', how='inner')
len(spg_filt)
# Out:
# 2421

# %%
#remove unnecessary columns

ng_filt = ng_filt[['Construct Barcode', 'Construct IDs','AvgHAP1_Meljuso;z-score;NG-ABE',
       'ABE Mutation Bin', 'Residues', 'ABE Median Residues', 'PAM']]

spg_filt = spg_filt[['Construct Barcode', 'Construct IDs','AvgHAP1_Meljuso;z-score;SpG-ABE',
       'ABE Mutation Bin', 'Residues', 'ABE Median Residues']]

# %%
#merge on guides that are intermediate/active with both enzymes

shared_ng_spg = pd.merge(ng_filt, spg_filt, on = 'Construct Barcode', how='inner')

# %%
len(shared_ng_spg)
# Out:
# 2133

# %%
gpp.set_aesthetics(context='paper')
ax= sns.scatterplot(x='AvgHAP1_Meljuso;z-score;NG-ABE', y='AvgHAP1_Meljuso;z-score;SpG-ABE',
               data = shared_ng_spg, hue='ABE Mutation Bin_x', palette= color_dictionary, linewidth=0, legend=False)

gpp.add_correlation(x='AvgHAP1_Meljuso;z-score;NG-ABE', y='AvgHAP1_Meljuso;z-score;SpG-ABE',
               data = shared_ng_spg)
sns.set(rc={'figure.figsize':(3,3)})
plt.xlabel('NG-ABE \n z-scored LFC')
plt.ylabel ('SpG-ABE \n z-scored LFC')
plt.axhline(-2, linestyle='dashed', color = 'black')
plt.axhline(-4, linestyle='dashed', color = 'black')
plt.axvline(-2, linestyle='dashed', color = 'black')
plt.axvline(-4, linestyle='dashed', color = 'black')
#ax.legend(facecolor='white', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlim(-12.5,5)
plt.ylim(-12.5,5)
#plt.savefig('ng abe vs spg abe.pdf', bbox_inches='tight', dpi=1000, transparent=True)
# Out:
# (-12.5, 5.0)
